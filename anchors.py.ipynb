# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("cleaned.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  roundId  roundNumber  roundTimeMillis  \
# 0          10            10  1236839            2            39807
# 1         273           273  1236839            2            39807
# 2         536           536  1236839            2            39807
# 3         799           799  1236839            2            39807
# 4          19            19  1236840            3             7680
#
#        killId  tradedByKillId  tradedForKillId  bombId  resId  ...  assists  \
# 0  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 1  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 2  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 3  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 4  10022974.0      10022976.0              NaN     NaN    NaN  ...       []
#
#   referencePlayerId  eventType damageType  weapon    impact  \
# ...

# %%
df.attackingTeamId.unique()
# Out:
# array([6344, 6426,  286,   17,  224,  603, 1625, 1264,  808,  305,   15],
#       dtype=int64)

# %%
ref = df.query
new = df.query("attackingTeamId == '6344 '") #drop all except
new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  roundId  roundNumber  roundTimeMillis  \
# 0          10            10  1236839            2            39807
# 1         273           273  1236839            2            39807
# 2         536           536  1236839            2            39807
# 3         799           799  1236839            2            39807
# 4          19            19  1236840            3             7680
#
#        killId  tradedByKillId  tradedForKillId  bombId  resId  ...  assists  \
# 0  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 1  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 2  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 3  10022966.0             NaN              NaN     NaN    NaN  ...       []
# 4  10022974.0      10022976.0              NaN     NaN    NaN  ...       []
#
#   referencePlayerId  eventType damageType  weapon    impact  \
# ...
